# %%
import datetime
import cv2, time

# %%
capture = cv2.VideoCapture(0)    # 0번 카메라를 켭니다.
capture.isOpened()
# Out:
# True

# %%
fourcc = cv2.VideoWriter_fourcc(*'DIVX') 
record = False
count = 1
key = 1

# %%
global capture, count, key

def img_capture():
    global capture, count
#     if(int(capture.get(1)) % 20 == 0):
    print('Saved frame number : ' + str(int(capture.get(1))))
    cv2.imwrite("D:/Fpjt/z_project/image/frame%d.jpg" % count, frame)
    print('Saved frame%d.jpg' % count)
    count += 1

# %%
capture = cv2.VideoCapture(0)  
if capture.isOpened():
    while True:
        ret, frame = capture.read()
        
        cv2.imshow("Video", frame)
        key = cv2.waitKey(1)

        if key == 27:           # 27 = ESC
            break
            
        elif key == 24:         # 26 = Ctrl + X
            record=True
            video = cv2.VideoWriter("D:/Fpjt/z_project/image/record.mp4", fourcc, 30.0, (frame.shape[1], frame.shape[0]))
        elif key == 3:          # 3 = Ctrl + C
            print("Record stop")
            record = False       
            video.release()
            
        if record == True:
            print("Record is running")
            video.write(frame)
            img_capture()
else:
    print("Camera is not opened")
            
capture.release()
cv2.destroyAllWindows()
# Out:
# Record is running
# Saved frame number : -1
# Saved frame189.jpg
# Record is running
# Saved frame number : -1
# Saved frame190.jpg
# Record is running
# Saved frame number : -1
# Saved frame191.jpg
# Record is running
# Saved frame number : -1
# Saved frame192.jpg
# Record is running
# Saved frame number : -1
# Saved frame193.jpg
# Record is running
# Saved frame number : -1
# Saved frame194.jpg
# Record is running
# Saved frame number : -1
# Saved frame195.jpg
# Record is running
# Saved frame number : -1
# Saved frame196.jpg
# Record is running
# Saved frame number : -1
# Saved frame197.jpg
# Record is running
# Saved frame number : -1
# Saved frame198.jpg
# Record is running
# Saved frame number : -1
# Saved frame199.jpg
# Record is running
# Saved frame number : -1
# Saved frame200.jpg
# Record is running
# Saved frame number : -1
# Saved frame201.jpg
# Record is running
# Saved frame number : -1
# Saved frame202.jpg
# Record is running
# Saved frame number : -1
# Saved frame203.jpg
# Record is running
# Saved frame number : -1
# Saved frame204.jpg
# Record is running
# Saved frame number : -1
# Saved frame205.jpg
# Record is running
# Saved frame number : -1
# Saved frame206.jpg
# Record is running
# Saved frame number : -1
# Saved frame207.jpg
# Record is running
# Saved frame number : -1
# Saved frame208.jpg
# Record is running
# Saved frame number : -1
# Saved frame209.jpg
# Record is running
# Saved frame number : -1
# Saved frame210.jpg
# Record is running
# Saved frame number : -1
# Saved frame211.jpg
# Record is running
# Saved frame number : -1
# Saved frame212.jpg
# Record is running
# Saved frame number : -1
# Saved frame213.jpg
# Record is running
# Saved frame number : -1
# Saved frame214.jpg
# Record is running
# Saved frame number : -1
# Saved frame215.jpg
# Record is running
# Saved frame number : -1
# Saved frame216.jpg
# Record is running
# Saved frame number : -1
# Saved frame217.jpg
# Record is running
# Saved frame number : -1
# Saved frame218.jpg
# Record is running
# Saved frame number : -1
# Saved frame219.jpg
# Record is running
# Saved frame number : -1
# Saved frame220.jpg
# Record is running
# Saved frame number : -1
# Saved frame221.jpg
# Record is running
# Saved frame number : -1
# Saved frame222.jpg
# Record is running
# Saved frame number : -1
# Saved frame223.jpg
# Record is running
# Saved frame number : -1
# Saved frame224.jpg
# Record is running
# Saved frame number : -1
# Saved frame225.jpg
# Record is running
# Saved frame number : -1
# Saved frame226.jpg
# Record is running
# Saved frame number : -1
# Saved frame227.jpg
# Record is running
# Saved frame number : -1
# Saved frame228.jpg
# Record is running
# Saved frame number : -1
# Saved frame229.jpg
# Record is running
# Saved frame number : -1
# Saved frame230.jpg
# Record is running
# Saved frame number : -1
# Saved frame231.jpg
# Record is running
# Saved frame number : -1
# Saved frame232.jpg
# Record is running
# Saved frame number : -1
# Saved frame233.jpg
# Record is running
# Saved frame number : -1
# Saved frame234.jpg
# Record is running
# Saved frame number : -1
# Saved frame235.jpg
# Record is running
# Saved frame number : -1
# Saved frame236.jpg
# Record is running
# Saved frame number : -1
# Saved frame237.jpg
# Record is running
# Saved frame number : -1
# Saved frame238.jpg
# Record is running
# Saved frame number : -1
# Saved frame239.jpg
# Record is running
# Saved frame number : -1
# Saved frame240.jpg
# Record is running
# Saved frame number : -1
# Saved frame241.jpg
# Record is running
# Saved frame number : -1
# Saved frame242.jpg
# Record is running
# Saved frame number : -1
# Saved frame243.jpg
# Record is running
# Saved frame number : -1
# Saved frame244.jpg
# Record is running
# Saved frame number : -1
# Saved frame245.jpg
# Record is running
# Saved frame number : -1
# Saved frame246.jpg
# Record is running
# Saved frame number : -1
# Saved frame247.jpg
# Record is running
# Saved frame number : -1
# Saved frame248.jpg
# Record is running
# Saved frame number : -1
# Saved frame249.jpg
# Record is running
# Saved frame number : -1
# Saved frame250.jpg
# Record is running
# Saved frame number : -1
# Saved frame251.jpg
# Record is running
# Saved frame number : -1
# Saved frame252.jpg
# Record is running
# Saved frame number : -1
# Saved frame253.jpg
# Record is running
# Saved frame number : -1
# Saved frame254.jpg
# Record is running
# Saved frame number : -1
# Saved frame255.jpg
# Record is running
# Saved frame number : -1
# Saved frame256.jpg
# Record is running
# Saved frame number : -1
# Saved frame257.jpg
# Record is running
# Saved frame number : -1
# Saved frame258.jpg
# Record is running
# Saved frame number : -1
# Saved frame259.jpg
# Record is running
# Saved frame number : -1
# Saved frame260.jpg
# Record is running
# Saved frame number : -1
# Saved frame261.jpg
# Record is running
# Saved frame number : -1
# Saved frame262.jpg
# Record is running
# Saved frame number : -1
# Saved frame263.jpg
# Record is running
# Saved frame number : -1
# Saved frame264.jpg
# Record is running
# Saved frame number : -1
# Saved frame265.jpg
# Record is running
# Saved frame number : -1
# Saved frame266.jpg
# Record is running
# Saved frame number : -1
# Saved frame267.jpg
# Record is running
# Saved frame number : -1
# Saved frame268.jpg
# Record is running
# Saved frame number : -1
# Saved frame269.jpg
# Record is running
# Saved frame number : -1
# Saved frame270.jpg
# Record is running
# Saved frame number : -1
# Saved frame271.jpg
# Record is running
# Saved frame number : -1
# Saved frame272.jpg
# Record is running
# Saved frame number : -1
# Saved frame273.jpg
# Record is running
# Saved frame number : -1
# Saved frame274.jpg
# Record is running
# Saved frame number : -1
# Saved frame275.jpg
# Record is running
# Saved frame number : -1
# Saved frame276.jpg
# Record is running
# Saved frame number : -1
# Saved frame277.jpg
# Record is running
# Saved frame number : -1
# Saved frame278.jpg
# Record is running
# Saved frame number : -1
# Saved frame279.jpg
# Record is running
# Saved frame number : -1
# Saved frame280.jpg
# Record stop

# %%
now = datetime.datetime.now().strftime("%Y-%m-%d_%H_%M_%S")
import os
path_="D:/Fpjt/z_project/image/"
os.rename(path_+"record.mp4",path_+str(now)+".mp4")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-28-c79306fe812a> in <module>
#       2 import os
#       3 path_="D:/Fpjt/z_project/image/"
# ----> 4 os.rename(path_+"record.avi",path_+str(now)+".avi")
#
# FileNotFoundError: [WinError 2] 지정된 파일을 찾을 수 없습니다: 'D:/Fpjt/z_project/image/record.avi' -> 'D:/Fpjt/z_project/image/2020-08-07_19_18_35.avi'
